# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abd481/Search-Ranks-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 1. Refresh / Content Opportunity Scoring
#
# *I chose this lane because there are many pages that need to be reviewed, but content teams have limited resources. An ML-based scoring system can help prioritize important pages and identify which pages should be reviewed first.*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# *My work improves the decision of which content pages should be prioritized for review first. The content and SEO teams will use the ranked list to decide which pages should be investigated and potentially refreshed.*
#
# *A wrong recommendation can waste time and resources by focusing on pages with low potential, or it can cause the team to miss valuable opportunities from pages that should have been reviewed.*

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd 

df = pd.read_csv('/Users/abdelrahmansayed/FlyRank Projects/flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv')

(df['impressions_90d']>100).sum()
# Out:
# np.int64(21994)

# %% [markdown]
# *The dataset contains 30,000 content pages, which makes manual prioritization difficult. This creates an opportunity for a scoring system that helps identify which pages should be reviewed first.*
#
# *The dataset also shows that pages have different levels of visibility and performance. For example, the average number of impressions in the last 90 days is around 5,200 per page, and the average CTR is around 0.51%, showing that pages have different search performance patterns that can be used as signals for prioritization.*

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *My work can identify pages that are high-priority candidates for review based on observed signals such as search performance, engagement, content age, and visibility metrics.*
#
# *The output will be a decision-support tool that helps content and SEO teams prioritize which pages to investigate first. It can show patterns and rank opportunities based on the available data.*
#
# *However, this work cannot prove that refreshing a page will cause traffic growth or guarantee success after making changes. It also cannot predict Google's algorithm or claim to know exactly how search rankings will change.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✔️] Every section above is filled — markdown thinking AND the code that backs it
# - [✔️] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✔️] No client names, URLs, or private queries anywhere
# - [✔️ ] My claims use careful words: observed, measured, directional, decision-support
# - [✔️ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
